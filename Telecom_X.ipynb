# %% [markdown]
# <a href="https://colab.research.google.com/github/Starred21/protafolioA/blob/main/Telecom_X.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
url = 'https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'

# %%
# Validate the data
try:
    datos = pd.read_json(url)
    print("Data loaded successfully.")
    display(datos.head())

    # Check for missing values
    print("\nMissing values per column:")
    display(datos.isnull().sum())

except Exception as e:
    print(f"Error loading or processing data: {e}")
# Out:
# Data loaded successfully.
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# ...

# %%
# Flatten the 'customer' column
customer_data = pd.json_normalize(datos['customer'])
customer_data.columns = ['customer_' + col for col in customer_data.columns] # Rename columns
datos = pd.concat([datos, customer_data], axis=1)
display(datos.head())
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
# Flatten the 'internet' column
internet_data = pd.json_normalize(datos['internet'])
internet_data.columns = ['internet_' + col for col in internet_data.columns] # Rename columns
datos = pd.concat([datos, internet_data], axis=1)
display(datos.head())
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
# Convert 'Yes' and 'No' to 1 and 0 in relevant columns
yes_no_cols = [col for col in datos.columns if datos[col].dtype == 'object' and datos[col].isin(['Yes', 'No', 'No internet service', 'No phone service']).any()]
for col in yes_no_cols:
    datos[col] = datos[col].replace({'Yes': 1, 'No': 0, 'No internet service': 0, 'No phone service': 0})

# Ensure 'customer_SeniorCitizen' is numeric
datos['customer_SeniorCitizen'] = pd.to_numeric(datos['customer_SeniorCitizen'])

# Handle 'TotalCharges' which might be strings and contain empty strings
datos['account_TotalCharges'] = pd.to_numeric(datos['account_TotalCharges'], errors='coerce')
datos['account_TotalCharges'] = datos['account_TotalCharges'].fillna(0) # Fill missing values with 0

# Calculate daily value (avoid division by zero for tenure=0)
datos['daily_value'] = datos.apply(lambda row: row['account_TotalCharges'] / row['customer_tenure'] if row['customer_tenure'] > 0 else 0, axis=1)

display(datos[['customerID', 'Churn', 'customer_tenure', 'account_TotalCharges', 'daily_value']].head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-11-1480415151.py in <cell line: 0>()
#       1 # Convert 'Yes' and 'No' to 1 and 0 in relevant columns
# ----> 2 yes_no_cols = [col for col in datos.columns if datos[col].dtype == 'object' and datos[col].isin(['Yes', 'No', 'No internet service', 'No phone service']).any()]
#       3 for col in yes_no_cols:
#       4     datos[col] = datos[col].replace({'Yes': 1, 'No': 0, 'No internet service': 0, 'No phone service': 0})
#       5
#
# /tmp/ipython-input-11-1480415151.py in <listcomp>(.0)
#       1 # Convert 'Yes' and 'No' to 1 and 0 in relevant columns
# ----> 2 yes_no_cols = [col for col in datos.columns if datos[col].dtype == 'object' and datos[col].isin(['Yes', 'No', 'No internet service', 'No phone service']).any()]
#       3 for col in yes_no_cols:
# ...

# %%
# Perform descriptive analysis on numerical columns
display(datos.describe())
# Out:
#        customer_SeniorCitizen  customer_Partner  customer_Dependents  \
# count             7267.000000       7267.000000          7267.000000
# mean                 0.162653          0.484106             0.300124
# std                  0.369074          0.499782             0.458343
# min                  0.000000          0.000000             0.000000
# 25%                  0.000000          0.000000             0.000000
# 50%                  0.000000          0.000000             0.000000
# 75%                  0.000000          1.000000             1.000000
# max                  1.000000          1.000000             1.000000
#
#        customer_tenure  internet_OnlineSecurity  internet_OnlineBackup  \
# count      7267.000000              7267.000000            7267.000000
# mean         32.346498                 0.285950               0.344571
# std          24.571773                 0.451897               0.475261
# ...
