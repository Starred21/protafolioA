# %% [markdown]
# <a href="https://colab.research.google.com/github/Starred21/protafolioA/blob/main/inmoviliaria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #problema#
#
# Hemos sido contratados como científicos de datos por una empresa inmobiliaria. Nuestra principal función es brindar soporte a las demandas del equipo de Aprendizaje Automático y del equipo de Desarrollo de esta empresa.
#
# Para atender a estas demandas, se ha proporcionado un tablero en Trello con las etapas y tareas del proyecto que debemos realizar. También se nos ha proporcionado una base de datos que utilizaremos para desarrollar el proyecto.
#
# La base de datos que vamos a utilizar para desarrollar el proyecto es una base de datos que contiene información sobre diferentes tipos de propiedades en Ciudad de México (CDMX), como departamentos, casas, locales comerciales, entre otros.
#
# En esta base de datos, encontraremos información sobre los valores de alquiler de cada propiedad, los costos de condominio, impuestos inmobiliarios y también sus características, como el número de habitaciones, suites, garages, etc.

# %% [markdown]
# ##importacion de datos##

# %%
import pandas as pd

url = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'
pd.read_csv(url, sep=';')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
df = pd.read_csv(url, sep=';')
df.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# ##¿Cuáles son los valores promedio de alquiler por tipo de propiedad?##

# %%
df['Valor'].mean()
# Out:
# np.float64(36885.05048392878)

# %%
df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %%
df.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
df.Tipo.value_counts()
# Out:
# Tipo
# Departamento                  14764
# Conjunto Comercial/Sala        5681
# Tienda/Salón                   1098
# Cocineta                        726
# Casa de Condominio              610
# Casa                            545
# Departamento en Hotel           455
# Galpón/Depósito/Almacén         289
# Edificio Completo               217
# Casa Comercial                  202
# Tienda en Centro Comercial      197
# Casa de Vecindad                158
# Cochera/Estacionamiento          77
# Terreno Estándar                 45
# Loft                             38
# Rancho                            8
# Estudio                           4
# Loteo/Condominio                  3
# Hotel                             2
# Posada/Chalé                      1
# Industria                         1
# Name: count, dtype: int64

# %%
df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento                  0.587715
# Conjunto Comercial/Sala       0.226145
# Tienda/Salón                  0.043708
# Cocineta                      0.028900
# Casa de Condominio            0.024282
# Casa                          0.021695
# Departamento en Hotel         0.018112
# Galpón/Depósito/Almacén       0.011504
# Edificio Completo             0.008638
# Casa Comercial                0.008041
# Tienda en Centro Comercial    0.007842
# Casa de Vecindad              0.006290
# Cochera/Estacionamiento       0.003065
# Terreno Estándar              0.001791
# Loft                          0.001513
# Rancho                        0.000318
# Estudio                       0.000159
# Loteo/Condominio              0.000119
# Hotel                         0.000080
# Posada/Chalé                  0.000040
# Industria                     0.000040
# Name: proportion, dtype: float64

# %% [markdown]
# ###tratando datos nulos###

# %%
df.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 0      False    False         False    False   False  False  False
# 1      False    False         False    False   False  False  False
# 2      False    False         False    False   False  False  False
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25116  False    False         False    False   False  False  False
# 25117  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
# 25120  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 0           False     False
# 1            True      True
# 2           False     False
# 3           False     False
# ...

# %%
df.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor             14
# Condominio      2626
# Impuesto        7084
# dtype: int64

# %%
df.fillna(0)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# ### Remover registros inconsistentes

# %%
df.query('Valor == 0 | Condominio == 0')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 1                         Casa               Polanco             2        0
# 5           Casa de Condominio              Santa Fe             5        4
# 7                 Departamento      Centro Histórico             1        0
# 11           Edificio Completo                  Roma             0        0
# 24     Conjunto Comercial/Sala              Santa Fe             0        1
# ...                        ...                   ...           ...      ...
# 25055  Conjunto Comercial/Sala               Polanco             1        3
# 25086                     Casa             Zacatenco             2        1
# 25098             Tienda/Salón  Lomas de Chapultepec             0        0
# 25099                     Casa      Centro Histórico             5        0
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
df.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([    1,     5,     7,    11,    24,    49,    53,    74,    78,    96,
#        ...
#        25010, 25014, 25029, 25032, 25053, 25055, 25086, 25098, 25099, 25116],
#       dtype='int64', length=2638)

# %%
df_remove = df.query('Valor == 0 | Condominio == 0').index

# %%
df.drop(df_remove,axis=0, inplace=True)

# %%
df.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([], dtype='int64')

# %% [markdown]
# ###filtros

# %% [markdown]
# debemos filtar solo los departamentos menores a $4500

# %%
df['Tipo'].unique()
# Out:
# array(['Cocineta', 'Conjunto Comercial/Sala', 'Departamento',
#        'Departamento en Hotel', 'Casa de Condominio', 'Tienda/Salón',
#        'Casa', 'Casa Comercial', 'Loft', 'Tienda en Centro Comercial',
#        'Galpón/Depósito/Almacén', 'Edificio Completo', 'Casa de Vecindad',
#        'Cochera/Estacionamiento', 'Posada/Chalé', 'Estudio'], dtype=object)

# %%
df.query('Tipo == "Departamento" & Habitaciones == 1 & Valor < 4500')
# Out:
#                Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3      Departamento  Centro Histórico             1        0       0    15
# 4      Departamento         Del Valle             1        0       0    48
# 19     Departamento          Narvarte             1        0       0    48
# 37     Departamento  Centro Histórico             1        0       0    27
# 61     Departamento  Centro Histórico             1        1       0    37
# ...             ...               ...           ...      ...     ...   ...
# 24710  Departamento         Nativitas             1        0       0    40
# 24872  Departamento        Peralvillo             1        0       1    69
# 24880  Departamento        La Condesa             1        0       0    46
# 24943  Departamento              Roma             1        0       0    21
# 25114  Departamento          Narvarte             1        0       0    28
#
#         Valor  Condominio  Impuesto
# ...

# %%
filtro_depto = df.query('Tipo == "Departamento" & Habitaciones == 1 & Valor < 4500')

# %%
seccion1 = df.query('Tipo == "Departamento" & Habitaciones >= 2')

# %%
seccion2 = df.query('Valor < 10500 & Area >= 70')

# %%
filtro2 = df.query('Tipo == "Departamento" & Habitaciones >= 2 & Valor < 10500 & Area >= 70')

# %% [markdown]
# ##guardando datos en formato CSV

# %%
df.to_csv('inmuebles.csv')

# %%
 filtro2.to_csv('filtro2.csv')

# %% [markdown]
# ##Demandas DEV

# %% [markdown]
# ###Crear columnas numericas

# %%
datos = pd.read_csv('filtro2.csv', sep=',')
datos.head()
# Out:
#    Unnamed: 0          Tipo   Colonia  Habitaciones  Garages  Suites  Area  \
# 0          14  Departamento  Narvarte             2        1       0   110
# 1          16  Departamento  Narvarte             2        1       0    78
# 2          21  Departamento      Roma             2        1       0    76
# 3          28  Departamento  Santa Fe             3        1       2    70
# 4          33  Departamento  Santa Fe             3        1       1    72
#
#     Valor  Condominio  Impuesto
# 0  6650.0      2450.0     483.0
# 1  7000.0      2450.0       0.0
# 2  8750.0      2590.0       0.0
# 3  6300.0      3832.5     490.0
# 4  8225.0      2100.0     245.0

# %%
datos['Valor_mensual'] = datos['Valor'] + datos['Condominio']

# %%
datos.head()
# Out:
#    Unnamed: 0          Tipo   Colonia  Habitaciones  Garages  Suites  Area  \
# 0          14  Departamento  Narvarte             2        1       0   110
# 1          16  Departamento  Narvarte             2        1       0    78
# 2          21  Departamento      Roma             2        1       0    76
# 3          28  Departamento  Santa Fe             3        1       2    70
# 4          33  Departamento  Santa Fe             3        1       1    72
#
#     Valor  Condominio  Impuesto  Valor_mensual
# 0  6650.0      2450.0     483.0         9100.0
# 1  7000.0      2450.0       0.0         9450.0
# 2  8750.0      2590.0       0.0        11340.0
# 3  6300.0      3832.5     490.0        10132.5
# 4  8225.0      2100.0     245.0        10325.0

# %%
datos['Descripcion'] = datos['Tipo'] + 'en la colonia ' + datos['Colonia']

# %%
datos
# Out:
#       Unnamed: 0          Tipo    Colonia  Habitaciones  Garages  Suites  \
# 0             14  Departamento   Narvarte             2        1       0
# 1             16  Departamento   Narvarte             2        1       0
# 2             21  Departamento       Roma             2        1       0
# 3             28  Departamento   Santa Fe             3        1       2
# 4             33  Departamento   Santa Fe             3        1       1
# ...          ...           ...        ...           ...      ...     ...
# 3018       25028  Departamento  Del Valle             2        0       1
# 3019       25062  Departamento   Santa Fe             2        1       1
# 3020       25063  Departamento   Narvarte             3        1       0
# 3021       25105  Departamento   Santa Fe             2        1       1
# 3022       25106  Departamento   Santa Fe             3        2       0
#
#       Area   Valor  Condominio  Impuesto  Valor_mensual  \
# ...
